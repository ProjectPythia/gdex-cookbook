# %% [markdown]
# # General Circulation Model (GCM) Output Workflow

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
#
# GDEX hosts output from various General Circulation Models (GCMs), including CMIP-era simulations. This notebook demonstrates how to access and analyze GCM output from GDEX.
#
# 1. Locate a GCM dataset on GDEX
# 2. Access model output via the GDEX API or THREDDS
# 3. Inspect model metadata (grid, variables, temporal coverage)
# 4. Compute a temporal or spatial diagnostic

# %% [markdown]
# ## Prerequisites
#
# | Concepts | Importance | Notes |
# | --- | --- | --- |
# | zarr_intro or tds_intro | Necessary | At least one GDEX access method |
# | [xarray](https://xarray.pydata.org) | Necessary | |
# | [cf_xarray](https://cf-xarray.readthedocs.io) | Helpful | CF-compliant coordinate handling |
# | [Dask](https://dask.org) | Helpful | Large ensemble data |
#
# - **Time to learn**: 35 minutes

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cf_xarray

# %% [markdown]
# ## Finding a GCM Dataset on GDEX
#
# Search the GDEX catalog for GCM datasets. Use the API to check spatial/temporal coverage and available variables.

# %%
# TODO: search for GCM datasets
# import requests
# datasets = requests.get("https://gdex.ucar.edu/api/datasets/").json()
# gcm_ds = [d for d in datasets["data"]["datasets"] if "CMIP" in d["title"] or "GCM" in d["title"]]
# print(gcm_ds[:5])

# %% [markdown]
# ## Accessing GCM Output

# %%
# TODO: open GCM dataset
DSID = "d######"  # replace with actual dataset ID
# ds = xr.open_zarr("https://...", chunks="auto")  # ARCO/Zarr
# -- or --
# ds = xr.open_dataset("https://thredds.rda.ucar.edu/thredds/dodsC/...")  # OPeNDAP

# %% [markdown]
# ## Inspecting Model Metadata
#
# GCM output typically follows CF conventions. `cf_xarray` simplifies working with CF-compliant coordinates and attributes.

# %%
# TODO: inspect dataset structure and CF metadata
# print(ds.cf)
# print(ds.cf.coordinates)

# %% [markdown]
# ## Computing a Diagnostic

# %%
# TODO: compute a climatology or trend
# tas_clim = ds.cf["air_temperature"].mean("time").compute()

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
#
# GCM output on GDEX follows CF conventions and is accessible via the same THREDDS and ARCO interfaces as reanalysis data. cf_xarray simplifies working with CF-compliant metadata.
#
# ### What's next?
#
# See `data_fusion.ipynb` to compare GCM output with reanalysis, or `observations.ipynb` to validate against observations.

# %% [markdown]
# ## Resources and References
#
# - [CMIP6 documentation](https://pcmdi.llnl.gov/CMIP6/)
# - [cf_xarray documentation](https://cf-xarray.readthedocs.io)
# - [GDEX Dataset Catalog](https://gdex.ucar.edu/datasets/)

# %% [markdown]
# # Observational Data Workflow

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
#
# GDEX hosts a range of in-situ and remote-sensing observational datasets. This notebook demonstrates how to discover, access, and work with observational data from GDEX.
#
# 1. Discover observational datasets on GDEX
# 2. Access and load an observational dataset
# 3. Basic quality screening
# 4. Visualize observations on a map

# %% [markdown]
# ## Prerequisites
#
# | Concepts | Importance | Notes |
# | --- | --- | --- |
# | gdex_intro | Necessary | GDEX dataset IDs and API basics |
# | [xarray](https://xarray.pydata.org) | Necessary | |
# | [pandas](https://pandas.pydata.org) | Helpful | Tabular in-situ data |
# | [cartopy](https://scitools.org.uk/cartopy) | Helpful | Station/gridded maps |
#
# - **Time to learn**: 30 minutes

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %%
import requests
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %% [markdown]
# ## Discovering Observational Datasets
#
# Search the GDEX catalog for observation-based datasets. Filter by data type using `GET /api/datasets/{dsid}/data_types/` (look for `Point` or `Station` types).

# %%
BASE_URL = "https://gdex.ucar.edu"
# TODO: list datasets and filter for observational types
# datasets = requests.get(f"{BASE_URL}/api/datasets/").json()
# for ds in datasets["data"]["datasets"]:
#     types = requests.get(f"{BASE_URL}/api/datasets/{ds['id']}/data_types/").json()
#     if "Point" in types.get("data", {}).get("data_types", []):
#         print(ds["id"], ds["title"])

# %% [markdown]
# ## Accessing and Loading Observations

# %%
# TODO: open an observational dataset
DSID = "d######"  # replace with actual observational dataset ID
# ds = xr.open_dataset("https://...")  # OPeNDAP or local file

# %% [markdown]
# ## Quality Screening
#
# Apply basic quality flags or value-range checks appropriate to the dataset. Consult the dataset documentation for standard QC procedures.

# %%
# TODO: apply quality screening
# valid = ds.where(ds["obs_variable"] > -9999)  # mask fill values
# valid = valid.where(valid["qc_flag"] == 0)   # keep only QC-passed values

# %% [markdown]
# ## Visualization

# %%
# TODO: plot station data or gridded observations on a map
# fig, ax = plt.subplots(subplot_kw={"projection": ccrs.PlateCarree()})
# ax.scatter(ds.longitude, ds.latitude, c=ds["obs_variable"].isel(time=0), transform=ccrs.PlateCarree())
# ax.coastlines()
# plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
#
# GDEX observational datasets span in-situ, radiosonde, radar, and satellite sources. Always check data type (Point vs. Grid) and consult dataset documentation for QC procedures before analysis.
#
# ### What's next?
#
# See `data_fusion.ipynb` to combine observations with model or reanalysis data for validation.

# %% [markdown]
# ## Resources and References
#
# - [GDEX Dataset Catalog](https://gdex.ucar.edu/datasets/)
# - [xarray documentation](https://xarray.pydata.org)
# - [pandas documentation](https://pandas.pydata.org)

# %% [markdown]
# # Getting Help with GDEX

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
#
# This notebook shows how to find support resources for GDEX datasets, including contacting dataset curators, browsing dataset documentation, and discovering related software and resources.
#
# 1. Retrieve GDEX staff contacts via the API
# 2. Access dataset-specific documentation
# 3. Find related software and external resources

# %% [markdown]
# ## Prerequisites
#
# | Concepts | Importance | Notes |
# | --- | --- | --- |
# | gdex_intro | Necessary | Familiarity with GDEX dataset IDs and the API |
#
# - **Time to learn**: 10 minutes

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %%
import requests
import json

# %% [markdown]
# ## Finding GDEX Staff Contacts
#
# `GET /api/get_staff/` lists all GDEX staff. `GET /api/get_staff/{dsid}/` returns the curators for a specific dataset.

# %%
# TODO: list staff for a specific dataset
BASE_URL = "https://gdex.ucar.edu"
DSID = "d633000"
# staff = requests.get(f"{BASE_URL}/api/get_staff/{DSID}/").json()
# print(staff)

# %% [markdown]
# ## Dataset Documentation
#
# `GET /api/datasets/{dsid}/documentation/` returns links to technical documentation, user guides, and related papers.

# %%
# TODO: retrieve documentation links
# docs = requests.get(f"{BASE_URL}/api/datasets/{DSID}/documentation/").json()
# for item in docs["data"]:
#     print(item)

# %% [markdown]
# ## Related Software and Resources
#
# `GET /api/datasets/{dsid}/resources/` and `GET /api/datasets/{dsid}/software/` list tools and utilities associated with a dataset.

# %%
# TODO: retrieve related resources and software
# resources = requests.get(f"{BASE_URL}/api/datasets/{DSID}/resources/").json()
# software  = requests.get(f"{BASE_URL}/api/datasets/{DSID}/software/").json()

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
#
# GDEX provides programmatic access to staff contacts, documentation links, and related tools for each dataset. For direct support, email datahelp@ucar.edu.
#
# ### What's next?
#
# See `submission.ipynb` to learn how to submit a data request, or return to `gdex_intro.ipynb` for a broader overview.

# %% [markdown]
# ## Resources and References
#
# - [GDEX Help & Support](https://rda.ucar.edu/contact/)
# - datahelp@ucar.edu — GDEX data help desk
# - [GDEX API Documentation](https://gdex.ucar.edu/api/documentation/)

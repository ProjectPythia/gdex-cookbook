# %% [markdown]
# # Transferring GDEX Data with Globus

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
#
# Globus provides high-speed, reliable data transfer between GDEX and your institution or HPC system. The GDEX API can initiate a Globus transfer directly from a completed subset request.
#
# 1. Complete a GDEX subset request
# 2. Find your Globus endpoint UUID
# 3. Initiate the transfer via the GDEX API
# 4. Monitor transfer progress

# %% [markdown]
# ## Prerequisites
#
# | Concepts | Importance | Notes |
# | --- | --- | --- |
# | submission | Necessary | Completed GDEX data request with an rindex |
# | [Globus account](https://www.globus.org) | Necessary | And a Globus endpoint at your destination |
# | GDEX account and token | Necessary | |
#
# - **Time to learn**: 20 minutes

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %%
import requests
import json

# %% [markdown]
# ## Prerequisites: Completed Request and Globus Endpoint
#
# Before initiating a Globus transfer you need:
# - A completed GDEX request `rindex` (see `submission.ipynb`)
# - Your destination Globus endpoint UUID (find it at [app.globus.org](https://app.globus.org))

# %%
BASE_URL = "https://gdex.ucar.edu"
# TODO: set your request index and Globus endpoint
# TOKEN    = "your_gdex_token"
# RINDEX   = "your_rindex"
# ENDPOINT = "xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx"  # Globus endpoint UUID

# %% [markdown]
# ## Initiating the Transfer
#
# `GET /api/globus_download/{rindex}/{endpoint}` instructs GDEX to push the completed request files to your Globus endpoint.

# %%
# TODO: initiate the Globus transfer
# resp = requests.get(
#     f"{BASE_URL}/api/globus_download/{RINDEX}/{ENDPOINT}",
#     params={"token": TOKEN}
# )
# print(resp.json())

# %% [markdown]
# ## Monitoring the Transfer
#
# Track transfer progress at [app.globus.org/activity](https://app.globus.org/activity) or use the Globus SDK for programmatic monitoring.

# %%
# TODO: (optional) monitor with globus_sdk
# import globus_sdk
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
#
# Globus transfers are the recommended method for moving large GDEX datasets to HPC systems. The GDEX API can initiate the transfer directly from a completed request index.
#
# ### What's next?
#
# See `download_workflow.ipynb` for an HTTP download alternative, or `posix_intro.ipynb` for direct filesystem access on NCAR HPC.

# %% [markdown]
# ## Resources and References
#
# - [Globus](https://www.globus.org)
# - [Globus SDK for Python](https://globus-sdk-python.readthedocs.io)
# - [GDEX API Documentation](https://gdex.ucar.edu/api/documentation/)
